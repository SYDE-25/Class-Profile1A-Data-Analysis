# %%
import pandas as pd 
import seaborn as sns
import matplotlib.pyplot as plt
# %matplotlib inline
import numpy as np
pd.options.mode.chained_assignment = None

# %%
relevant_cols = ['Had you had sexual intercourse before starting university?']
sex_before_uni = class_df[relevant_cols]

sex_before_uni = sex_before_uni.dropna().reset_index()
sex_before_uni

# %%
sex_before_uni['Number of people'] = sex_before_uni.groupby(['Had you had sexual intercourse before starting university?'])['Had you had sexual intercourse before starting university?'].transform('count')
sex_before_uni.head()

# %%
sex_before_uni = sex_before_uni.drop_duplicates(subset=['Had you had sexual intercourse before starting university?', 'Number of people'], keep='first')
sex_before_uni

# %%
sex_before_uni = sex_before_uni.dropna()
sex_before_uni

# %%
plt.figure(figsize=(16,8))
ax1 = plt.subplot(121, aspect='equal')
plt.title("People Who Had Sex Before Uni", fontsize=18)
sex_before_uni.plot(kind='pie', y ='Number of people', ax=ax1, autopct='%1.1f%%', 
startangle=90, shadow=False, ylabel = '', labels=sex_before_uni['Had you had sexual intercourse before starting university?'], legend = False, fontsize=14)
# Out:
# <AxesSubplot:title={'center':'People Who Had Sex Before Uni'}>

# %%
relevant_cols = ['Have you had sexual intercourse since starting university?']
sex_during_uni = class_df[relevant_cols]

sex_during_uni.head()

# %%
sex_during_uni = sex_during_uni.dropna()

# %%
sex_during_uni['Number of people'] = sex_during_uni.groupby(['Have you had sexual intercourse since starting university?'])['Have you had sexual intercourse since starting university?'].transform('count')
sex_during_uni.head()

# %%
sex_during_uni = sex_during_uni.drop_duplicates(subset=['Have you had sexual intercourse since starting university?', 'Number of people'], keep='first')
sex_during_uni

# %%
plt.figure(figsize=(16,8))
ax1 = plt.subplot(121, aspect='equal')
plt.title("People Who Had Sex During Uni", fontsize=18)
sex_during_uni.plot(kind='pie', y ='Number of people', ax=ax1, autopct='%1.1f%%', 
startangle=90, shadow=False, ylabel = '', labels=sex_during_uni['Have you had sexual intercourse since starting university?'], legend = False, fontsize=14)
# Out:
# <AxesSubplot:title={'center':'People Who Had Sex During Uni'}>
