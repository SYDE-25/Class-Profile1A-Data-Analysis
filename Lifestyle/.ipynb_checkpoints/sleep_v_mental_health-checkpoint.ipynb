# %%
import pandas as pd 
import seaborn as sns
import matplotlib.pyplot as plt
# %matplotlib inline
import numpy as np
pd.options.mode.chained_assignment = None

# %%
class_df.columns
# Out:
# Index(['Timestamp', 'Ethnicity', 'What year were you born?',
#        'What is your gender?', 'What is your sexuality?',
#        'Political Alignment', 'Religion', 'What's your hometown?',
#        'Which country was your parent/guardian 1 born?',
#        'Which country was your parent/guardian 2 born?',
#        'Highest Parent Education',
#        'Did at least one of your parents pursue a degree/career in STEM?',
#        'Were you in a specialized high school program?',
#        'What was your top 6 highschool average for engineering? Please enter just the number with NO % sign (Calc, Adv Functions, English, Physics, Chemistry, 6th course in your top 6) ',
#        'What university would you go to if you were not going to Waterloo?',
#        'Out of the previously mentioned universities, were you accepted or rejected from your program? If you did not apply to the university, indicate as such [Carleton University]',
# ...

# %%
# Comparing sleep against mental health
relevant_cols = ['How many hours of sleep did you get per night during school weeks on average (Not including naps)', 'Rate your mental health during the term.']
sleep_v_mhealth = class_df[relevant_cols]

sleep_v_mhealth

# %%
sleep_v_mhealth.loc[sleep_v_mhealth['How many hours of sleep did you get per night during school weeks on average (Not including naps)'] == 4.0,'How many hours of sleep did you get per night during school weeks on average (Not including naps)'] = '4 - 5'
sleep_v_mhealth.loc[sleep_v_mhealth['How many hours of sleep did you get per night during school weeks on average (Not including naps)'] == 5.0,'How many hours of sleep did you get per night during school weeks on average (Not including naps)'] = '4 - 5'
sleep_v_mhealth.loc[sleep_v_mhealth['How many hours of sleep did you get per night during school weeks on average (Not including naps)'] == 6.0,'How many hours of sleep did you get per night during school weeks on average (Not including naps)'] = '6 - 7'
sleep_v_mhealth.loc[sleep_v_mhealth['How many hours of sleep did you get per night during school weeks on average (Not including naps)'] == 6.5,'How many hours of sleep did you get per night during school weeks on average (Not including naps)'] = '6 - 7'
sleep_v_mhealth.loc[sleep_v_mhealth['How many hours of sleep did you get per night during school weeks on average (Not including naps)'] == 7.0,'How many hours of sleep did you get per night during school weeks on average (Not including naps)'] = '6 - 7'
sleep_v_mhealth.loc[sleep_v_mhealth['How many hours of sleep did you get per night during school weeks on average (Not including naps)'] == 7.5,'How many hours of sleep did you get per night during school weeks on average (Not including naps)'] = '8 - 9'
sleep_v_mhealth.loc[sleep_v_mhealth['How many hours of sleep did you get per night during school weeks on average (Not including naps)'] == 7.6,'How many hours of sleep did you get per night during school weeks on average (Not including naps)'] = '8 - 9'
sleep_v_mhealth.loc[sleep_v_mhealth['How many hours of sleep did you get per night during school weeks on average (Not including naps)'] == 8.0,'How many hours of sleep did you get per night during school weeks on average (Not including naps)'] = '8 - 9'
sleep_v_mhealth.loc[sleep_v_mhealth['How many hours of sleep did you get per night during school weeks on average (Not including naps)'] == 8.5,'How many hours of sleep did you get per night during school weeks on average (Not including naps)'] = '8 - 9'
sleep_v_mhealth.loc[sleep_v_mhealth['How many hours of sleep did you get per night during school weeks on average (Not including naps)'] == 9.0,'How many hours of sleep did you get per night during school weeks on average (Not including naps)'] = '8 - 9'
sleep_v_mhealth.loc[sleep_v_mhealth['How many hours of sleep did you get per night during school weeks on average (Not including naps)'] == 9.5,'How many hours of sleep did you get per night during school weeks on average (Not including naps)'] = '10'
sleep_v_mhealth.loc[sleep_v_mhealth['How many hours of sleep did you get per night during school weeks on average (Not including naps)'] == 10.0,'How many hours of sleep did you get per night during school weeks on average (Not including naps)'] = '10'

sleep_v_mhealth

# %%
sleep_v_mhealth = sleep_v_mhealth.sort_values(['How many hours of sleep did you get per night during school weeks on average (Not including naps)'])

sleep_v_mhealth.dropna()
sleep_v_mhealth.head(20)

# %%
new_row1={"How many hours of sleep did you get per night during school weeks on average (Not including naps)": 10, "Rate your mental health during the term.": 9.0}
new_row2={"How many hours of sleep did you get per night during school weeks on average (Not including naps)": 10, "Rate your mental health during the term.": 4.0}
new_row3={"How many hours of sleep did you get per night during school weeks on average (Not including naps)": 10, "Rate your mental health during the term.": 5.0}
new_row4={"How many hours of sleep did you get per night during school weeks on average (Not including naps)": 10, "Rate your mental health during the term.": 7.0}
new_row5={"How many hours of sleep did you get per night during school weeks on average (Not including naps)": 10, "Rate your mental health during the term.": 6.0}

sleep_v_mhealth=sleep_v_mhealth.append(new_row1, ignore_index=True)
sleep_v_mhealth=sleep_v_mhealth.append(new_row2, ignore_index=True)
sleep_v_mhealth=sleep_v_mhealth.append(new_row3, ignore_index=True)
sleep_v_mhealth=sleep_v_mhealth.append(new_row4, ignore_index=True)
sleep_v_mhealth=sleep_v_mhealth.append(new_row5, ignore_index=True)

sleep_v_mhealth = sleep_v_mhealth.drop(labels=[3, 4, 34, 18, 83, 0, 1, 2], axis=0)

sleep_v_mhealth.head(100)

# %%
sleep_v_mhealth.loc[sleep_v_mhealth['How many hours of sleep did you get per night during school weeks on average (Not including naps)'] == 10.0,'How many hours of sleep did you get per night during school weeks on average (Not including naps)'] = '10'

# %%
sns.set(rc={'figure.figsize':(15, 9)})
sns.set(font_scale=1.25)
sns.set_theme(palette="colorblind")
fig, ax = plt.subplots()
sns.boxplot(x="How many hours of sleep did you get per night during school weeks on average (Not including naps)", y="Rate your mental health during the term.", data=sleep_v_mhealth, ax=ax, width=0.2)
plt.title("Hours of sleep vs Mental Health", fontsize=18, y=1.03)
plt.xlabel("Average hours of Sleep per day", labelpad=15, fontsize=16)
plt.ylabel("Mental health during 1A (Scale from 1-10)", labelpad=15, fontsize=16)

plt.show()
