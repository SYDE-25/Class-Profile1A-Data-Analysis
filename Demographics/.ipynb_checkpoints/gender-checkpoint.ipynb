# %%
import pandas as pd 
import seaborn as sns
import firebase_admin
from firebase_admin import credentials, firestore
import matplotlib.pyplot as plt
# %matplotlib inline
import numpy as np
pd.options.mode.chained_assignment = None

# %%
cols = ['What is your gender?']
df = class_df[cols].dropna().rename(columns={'What is your gender?': 'gender'})

df.head(100)

# %%
genders = df.groupby('gender')['gender'].count()
genders
# Out:
# gender
# Female        42
# Male          51
# Non-binary     1
# Name: gender, dtype: int64

# %%
total_res = 0
for gender in genders:
    total_res += gender

total_res
# Out:
# 94

# %%
pie, ax = plt.subplots(figsize=[10,6])
labels = genders.keys()
plt.pie(x=genders, autopct="%.1f%%", labels=labels, pctdistance=0.5)
plt.title("Genders in SYDE 2025", fontsize=14);
pie.savefig("outputs/gender.png")
