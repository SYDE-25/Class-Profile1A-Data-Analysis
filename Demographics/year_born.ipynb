# %%
import firebase_admin
from firebase_admin import credentials, firestore
import pandas as pd 
import seaborn as sns
import math
import matplotlib.pyplot as plt
# %matplotlib inline
import numpy as np
pd.options.mode.chained_assignment = None

# %%
cols = ['What year were you born?']
df = class_df[cols].dropna()
df = df.astype('int64')
df

# %%
years = df.groupby('What year were you born?')['What year were you born?'].count()
years
# Out:
# What year were you born?
# 2001     5
# 2002    86
# 2003     3
# Name: What year were you born?, dtype: int64

# %%
total_responses = 0
for year in years:
    total_responses += int(year)
total_responses
# Out:
# 94

# %%
pie, ax = plt.subplots(figsize=[10,6])
labels = years.keys()
plt.pie(x=years, autopct="%.1f%%", labels=labels, pctdistance=0.5)
plt.title("What year was SYDE 2025 born in?", fontsize=14);
pie.savefig("outputs/year_born.png")
