# %%
import firebase_admin
from firebase_admin import credentials, firestore
import pandas as pd 
import seaborn as sns
import matplotlib.pyplot as plt
# %matplotlib inline
import numpy as np
pd.options.mode.chained_assignment = None

# %%
cols = ['Did at least one of your parents pursue a degree/career in STEM?']
df = class_df[cols].dropna().rename(columns={'Did at least one of your parents pursue a degree/career in STEM?': 'stem'})

df.head(100)

# %%
stem = df.groupby('stem')['stem'].count()
stem
# Out:
# stem
# No     29
# Yes    65
# Name: stem, dtype: int64

# %%
total = 0
for i in stem:
    total += i
total
# Out:
# 94

# %%
pie, ax = plt.subplots(figsize=[10,6])
labels = stem.keys()
plt.pie(x=stem, autopct="%.1f%%", labels=labels, pctdistance=0.5)
plt.title("Were SYDE 2025's Parents in Stem?", fontsize=14);
pie.savefig("outputs/stem.png")
